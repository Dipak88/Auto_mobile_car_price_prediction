# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
downloaded = drive.CreateFile({'id':'1UHJHfYufoW7UmMgCo4g-uc0HxaDVMFQi'}) # replace the id with id of file you want to access
downloaded.GetContentFile('AutoData.csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
auto1 = pd.read_csv("AutoData.csv")

# %%
auto1.head()
# Out:
#    symboling                      make fueltype  ... citympg highwaympg    price
# 0          3        alfa-romero giulia      gas  ...      21         27  13495.0
# 1          3       alfa-romero stelvio      gas  ...      21         27  16500.0
# 2          1  alfa-romero Quadrifoglio      gas  ...      19         26  16500.0
# 3          2               audi 100 ls      gas  ...      24         30  13950.0
# 4          2                audi 100ls      gas  ...      18         22  17450.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 	Perform EDA on the data

# %%
auto1.shape
# Out:
# (205, 25)

# %%
auto1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
# symboling           205 non-null int64
# make                205 non-null object
# fueltype            205 non-null object
# aspiration          205 non-null object
# doornumber          205 non-null object
# carbody             205 non-null object
# drivewheel          205 non-null object
# enginelocation      205 non-null object
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null object
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# horsepower          205 non-null int64
# ...

# %%
auto1.describe()
# Out:
#         symboling   wheelbase   carlength  ...     citympg  highwaympg         price
# count  205.000000  205.000000  205.000000  ...  205.000000  205.000000    205.000000
# mean     0.834146   98.756585  174.049268  ...   25.219512   30.751220  13276.710571
# std      1.245307    6.021776   12.337289  ...    6.542142    6.886443   7988.852332
# min     -2.000000   86.600000  141.100000  ...   13.000000   16.000000   5118.000000
# 25%      0.000000   94.500000  166.300000  ...   19.000000   25.000000   7788.000000
# 50%      1.000000   97.000000  173.200000  ...   24.000000   30.000000  10295.000000
# 75%      2.000000  102.400000  183.100000  ...   30.000000   34.000000  16503.000000
# max      3.000000  120.900000  208.100000  ...   49.000000   54.000000  45400.000000
#
# [8 rows x 15 columns]

# %%
plt.boxplot(auto1.price)
plt.show()

# %%
auto1.enginesize.plot.box()
plt.show()

# %%
auto1.horsepower.plot.box()
plt.show()

# %%
ct = auto1.fueltype.value_counts(normalize=True)
plt.bar(ct.index, ct.values)
plt.show()

# %%
auto1.fueltype.value_counts(normalize = True)
# Out:
# gas       0.902439
# diesel    0.097561
# Name: fueltype, dtype: float64

# %% [markdown]
# there is most of the cars is gas type

# %%
ct = auto1.carbody.value_counts(normalize=True)
plt.bar(ct.index, ct.values)
plt.show()

# %%
auto1.carbody.value_counts(normalize= True)
# Out:
# sedan          0.468293
# hatchback      0.341463
# wagon          0.121951
# hardtop        0.039024
# convertible    0.029268
# Name: carbody, dtype: float64

# %% [markdown]
# there is maxmium carbody are used in automobile is sedan and minimum is used convertile

# %%
ct = auto1.aspiration.value_counts(normalize=True)
plt.bar(ct.index, ct.values)
plt.show()

# %% [markdown]
# there is aspiration is in the std is used in automobile company

# %%
ct = auto1.cylindernumber.value_counts(normalize=True)
plt.bar(ct.index, ct.values)
plt.show()

# %% [markdown]
# there is maximum is used the four is cylindernumber that is used maximum in the automobile

# %%
ct = auto1.enginelocation.value_counts(normalize=True)
plt.bar(ct.index, ct.values)
plt.show()

# %% [markdown]
# there is maximum cars engine placed in the front

# %%
ct = auto1.enginetype.value_counts(normalize=True)
plt.bar(ct.index, ct.values)
plt.show()

# %%
sns.jointplot(x='enginesize' , y = 'price',data=auto1)
plt.show()

# %% [markdown]
# there is range for engineSize is 100 to 150 and price is 100000 to 200000

# %%
auto1.groupby('fueltype')['horsepower'].mean().plot.bar()
plt.show()

# %% [markdown]
# there is gas cars used the maximum horsepower

# %%
sns.jointplot(x='price' , y = 'horsepower',data=auto1)
plt.show()

# %% [markdown]
# there is maximum horsepower range is 50 to 150 maxmimum employees used this range horsepower cars.

# %%
sns.catplot(x="carbody", y="price",
            kind="swarm", data=auto1);

# %% [markdown]
# using the three varible at time creatig the suitable plot

# %%
auto1.groupby(['fueltype'])['carlength','carwidth','carheight'].mean().plot.barh()
plt.show()

# %% [markdown]
# there are different carbody is maximum used sedan and between price is 5000 to 10000 and maximum is above 400000

# %%
sns.pairplot(auto1)
plt.show()

# %%
auto1.columns
# Out:
# Index(['symboling', 'make', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
auto1.head()
# Out:
#    symboling                      make fueltype  ... citympg highwaympg    price
# 0          3        alfa-romero giulia      gas  ...      21         27  13495.0
# 1          3       alfa-romero stelvio      gas  ...      21         27  16500.0
# 2          1  alfa-romero Quadrifoglio      gas  ...      19         26  16500.0
# 3          2               audi 100 ls      gas  ...      24         30  13950.0
# 4          2                audi 100ls      gas  ...      18         22  17450.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ##	Perform data cleanup as required

# %%
auto1.isnull().sum()
# Out:
# symboling           0
# make                0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# there are not any null values in automobile data

# %%
auto1.drop(labels = 'make', axis = 1,inplace = False)
# Out:
#      symboling fueltype aspiration  ... citympg highwaympg    price
# 0            3      gas        std  ...      21         27  13495.0
# 1            3      gas        std  ...      21         27  16500.0
# 2            1      gas        std  ...      19         26  16500.0
# 3            2      gas        std  ...      24         30  13950.0
# 4            2      gas        std  ...      18         22  17450.0
# ..         ...      ...        ...  ...     ...        ...      ...
# 200         -1      gas        std  ...      23         28  16845.0
# 201         -1      gas      turbo  ...      19         25  19045.0
# 202         -1      gas        std  ...      18         23  21485.0
# 203         -1   diesel      turbo  ...      26         27  22470.0
# 204         -1      gas      turbo  ...      19         25  22625.0
#
# [205 rows x 24 columns]

# %% [markdown]
# ## Pick the best variable for making a simple linear regression model

# %%
corrs = auto1.corr()
corrs
# Out:
#                   symboling  wheelbase  ...  highwaympg     price
# symboling          1.000000  -0.531954  ...    0.034606 -0.079978
# wheelbase         -0.531954   1.000000  ...   -0.544082  0.577816
# carlength         -0.357612   0.874587  ...   -0.704662  0.682920
# carwidth          -0.232919   0.795144  ...   -0.677218  0.759325
# carheight         -0.541038   0.589435  ...   -0.107358  0.119336
# curbweight        -0.227691   0.776386  ...   -0.797465  0.835305
# enginesize        -0.105790   0.569329  ...   -0.677470  0.874145
# boreratio         -0.130051   0.488750  ...   -0.587012  0.553173
# stroke            -0.008735   0.160959  ...   -0.043931  0.079443
# compressionratio  -0.178515   0.249786  ...    0.265201  0.067984
# horsepower         0.070873   0.353294  ...   -0.770544  0.808139
# peakrpm            0.273606  -0.360469  ...   -0.054275 -0.085267
# citympg           -0.035823  -0.470414  ...    0.971337 -0.685751
# ...

# %% [markdown]
# there are many values but it is best varible choose for the give the maximum value to predict the price.and there is varible is enginetype

# %% [markdown]
# ## Perform train test split

# %%
x = auto1['enginesize'].values

# %%
y = auto1['price'].values

# %% [markdown]
# perform the train and test split on the x and y varible

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train ,y_test = train_test_split(x,y,test_size = 0.3,random_state=0)

# %%
x_train.shape , x_test.shape
# Out:
# ((143,), (62,))

# %% [markdown]
# fitting the simple linear_regression with x_train and y_train

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
x_train = x_train.reshape(-1,1)

# %%
y_train = y_train.reshape(-1,1)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.intercept_ , lr.coef_
# Out:
# (array([-7574.1315044]), array([[163.2907534]]))

# %% [markdown]
# predict the price which cars is best

# %%
x_test = x_test.reshape(-1,1)

# %%
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([[ 7285.32705489],
#        [18715.6797928 ],
#        [14633.41095783],
#        [ 2386.60445292],
#        [10224.56061606],
#        [16266.31849182],
#        [ 7448.61780829],
#        [ 7448.61780829],
#        [21981.49486077],
#        [ 7448.61780829],
#        [19205.552053  ],
#        [25573.89143555],
#        [ 3856.22123351],
#        [14306.82945103],
#        [ 7122.03630149],
#        [16266.31849182],
#        [13980.24794424],
#        [14633.41095783],
#        [10387.85136946],
#        [ 7448.61780829],
#        [10387.85136946],
#        [12020.75890345],
#        [13980.24794424],
#        [16266.31849182],
#        [20348.58732679],
#        [ 8265.07157528],
#        [ 8428.36232868],
#        [12020.75890345],
#        [ 8428.36232868],
#        [ 8265.07157528],
#        [10224.56061606],
#        [10224.56061606],
#        [17082.77225881],
#        [12347.34041025],
#        [ 8265.07157528],
#        [26553.63595594],
#        [10224.56061606],
# ...

# %%
y_test
# Out:
# array([ 6795. , 15750. , 15250. ,  5151. ,  9995. , 11199. ,  5389. ,
#         7898. , 17199. ,  6529. , 20970. , 31400.5, 10945. , 18344. ,
#         8916.5,  9989. ,  9295. , 18920. ,  7895. ,  6488. ,  9959. ,
#        15580. ,  9895. , 11549. , 15998. ,  5118. ,  6938. , 16695. ,
#         8358. ,  5499. ,  7975. , 12290. , 22018. ,  8948. ,  6849. ,
#        41315. , 11595. , 18150. ,  6377. , 45400. ,  8916.5, 17450. ,
#        34184. , 15040. , 11259. ,  7609. ,  7609. , 14869. , 11694. ,
#         8495. , 23875. ,  7099. ,  8058. , 10595. , 16503. , 18399. ,
#        10795. , 18420. ,  9960. ,  6229. ,  6479. , 15510. ])

# %% [markdown]
# ### predicting with training set

# %%
y_train_pred = lr.predict(x_train)

# %%
y_train_pred
# Out:
# array([[10387.85136946],
#        [12347.34041025],
#        [ 3856.22123351],
#        [21981.49486077],
#        [12347.34041025],
#        [ 7122.03630149],
#        [ 7448.61780829],
#        [ 8265.07157528],
#        [ 7285.32705489],
#        [ 8265.07157528],
#        [ 7285.32705489],
#        [10061.26986267],
#        [10061.26986267],
#        [17246.06301221],
#        [ 8265.07157528],
#        [12020.75890345],
#        [10061.26986267],
#        [17246.06301221],
#        [20348.58732679],
#        [19205.552053  ],
#        [ 8428.36232868],
#        [17246.06301221],
#        [10224.56061606],
#        [24104.27465496],
#        [11857.46815005],
#        [14633.41095783],
#        [15449.86472482],
#        [ 8428.36232868],
#        [12347.34041025],
#        [17246.06301221],
#        [12347.34041025],
#        [12347.34041025],
#        [17899.22602581],
#        [10551.14212286],
#        [10061.26986267],
#        [12020.75890345],
#        [42719.42054241],
# ...

# %%
y_train
# Out:
# array([[10295.   ],
#        [ 8495.   ],
#        [11845.   ],
#        [13499.   ],
#        [ 8189.   ],
#        [ 6295.   ],
#        [ 8778.   ],
#        [ 7999.   ],
#        [ 7395.   ],
#        [ 7995.   ],
#        [ 6095.   ],
#        [ 7053.   ],
#        [ 7126.   ],
#        [16900.   ],
#        [ 7499.   ],
#        [11900.   ],
#        [ 7463.   ],
#        [13860.   ],
#        [16558.   ],
#        [24565.   ],
#        [ 8558.   ],
#        [13200.   ],
#        [ 8195.   ],
#        [32528.   ],
#        [11048.   ],
#        [13295.   ],
#        [16845.   ],
#        [ 9258.   ],
#        [10245.   ],
#        [16500.   ],
#        [ 8845.   ],
#        [ 8921.   ],
#        [12764.   ],
#        [ 6785.   ],
#        [16430.   ],
#        [12440.   ],
#        [40960.   ],
#        [15985.   ],
#        [ 7775.   ],
#        [ 5348.   ],
#        [ 8249.   ],
#        [13950.   ],
#        [ 7349.   ],
#        [ 5572.   ],
#        [ 7738.   ],
# ...

# %%
plt.scatter(x_train,y_train ,color = 'Red')
plt.plot(x_train , lr.predict(x_train) ,color = 'Blue' )
plt.xlabel('EngineSize')
plt.ylabel('price')
plt.title('predicting the price with enginesize')
plt.show()

# %% [markdown]
# # Build model using best variable and report the R2

# %% [markdown]
# r2_score with the test set

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7797940080893313

# %% [markdown]
# r2_score with train set

# %%
r2_score(y_train_pred,y_train)
# Out:
# 0.6768806677745292

# %% [markdown]
# there is r2_score value is training set is 0.67 and test set is 0.77

# %% [markdown]
# # manual Make a multiple regression model

# %%
x1 = auto1[['enginesize','curbweight','horsepower','carwidth']]

# %%
y1 = auto1['price']

# %% [markdown]
# train_test_split with multiple_linear_regression

# %%
x1_train , x1_test , y1_train , y1_test = train_test_split(x1,y1,test_size = 0.3,random_state=0)

# %%
x1_train.shape , x1_test.shape
# Out:
# ((143, 4), (62, 4))

# %% [markdown]
# fitting the model with multiple varible

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr = LinearRegression()

# %%
mlr.fit(x1_train,y1_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# predicting the price with multiple variable

# %%
y_pred_mul = mlr.predict(x1_test)

# %%
r2_score(y_test,y_pred_mul)
# Out:
# 0.8141947436625151

# %% [markdown]
# predicting the price with multiple variable

# %%
y_pred_mul_train = mlr.predict(x1_train)

# %%
r2_score(y_train,y_pred_mul_train)
# Out:
# 0.818174411918832

# %% [markdown]
# ###  encoding the varible converted categorical into numeric

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LabelEncoder_x = LabelEncoder()

# %%
auto1['fueltype'] = LabelEncoder_x.fit_transform(auto1['fueltype'])

# %%
auto1['aspiration'] = LabelEncoder_x.fit_transform(auto1['aspiration'])

# %%
auto1['carbody'] = LabelEncoder_x.fit_transform(Auto1['carbody'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-410-d985f1f3b47b> in <module>()
# ----> 1 auto1['carbody'] = LabelEncoder_x.fit_transform(Auto1['carbody'])
#
# NameError: name 'Auto1' is not defined

# %%
auto1['drivewheel'] = LabelEncoder_x.fit_transform(Auto1['drivewheel'])

# %%
auto1['enginelocation'] = LabelEncoder_x.fit_transform(Auto1['enginelocation'])

# %%
auto1['fuelsystem'] = LabelEncoder_x.fit_transform(Auto1['fuelsystem'])

# %%
auto1['enginetype'] = LabelEncoder_x.fit_transform(Auto1['enginetype'])

# %%
auto1.columns

# %%
auto1['doornumber'] = auto1.doornumber.map({"two":2 ,"four":4 })

# %%
auto1['cylindernumber'] = auto1.cylindernumber.map({"four":4,"six":6,"five":5,"three":3,"twelve":12,"two":2,"eight":8})

# %%
auto1 = auto1.drop(labels = 'make', axis = 1,inplace = False)

# %%
auto1.head()

# %%
auto2 = auto1

# %%
auto2.head()

# %% [markdown]
# ## multiple linear Regression with all variable

# %%
x2 = auto2.drop('price' , axis = 1)

# %%
y2 = auto2[['price']]

# %%
x2

# %%
y2

# %% [markdown]
# #### train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size = 0.3,random_state = 0)

# %% [markdown]
# fitting the model with all variable

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr2 = LinearRegression()

# %%
mlr2.fit(x2_train,y2_train)

# %%
mlr2.intercept_ , mlr2.coef_

# %% [markdown]
# predicting the price with all variable

# %%
y_pred_mul2 = mlr2.predict(x2_test)

# %%
y_pred_mul2

# %%
y2_test

# %%
y_pred_mul22 = mlr2.predict(x2_train)

# %% [markdown]
# r2_score with train

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y2_train ,y_pred_mul22 )

# %% [markdown]
# r2_score with test

# %%
r2_score(y2_test,y_pred_mul2)

# %% [markdown]
# # feature selection using the multiple linear Regression

# %%
import statsmodels .api as sm

# %%
x_train_sm = sm.add_constant(x2_train)

# %%
lr_sm = sm.OLS(y2_train , x_train_sm).fit()

# %%
lr_sm.summary()

# %%
from sklearn.feature_selection import RFE

# %%
rfe = RFE(mlr2,10)

# %%
rfe.fit(x2_train,y2_train)

# %%
 feast = x2_train.columns[rfe.support_]

# %%
feast

# %%
x_train_sm2 = sm.add_constant(x2_train[feast])

# %%
lr_sm = sm.OLS(y2_train , x_train_sm2).fit()

# %%
lr_sm.summary()

# %% [markdown]
# # Final model should be interpretable

# %% [markdown]
# ### 	What is your understanding of the factors that drive price?

# %% [markdown]
# Determine the different model simple Regression and multiple linear regression with analaysis then different factor are affectd on the car price

# %% [markdown]
# like as car carbody  , enginesize,fueltype , curbweight,carwidth , it is all variable increases then
# car price increases in the automobile company .
